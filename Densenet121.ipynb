# %% [markdown]
# ## Import dependencies

# %%
import tensorflow as tf
from tensorflow.keras.layers import Layer
import numpy as np
from scipy.fftpack import dct
import numpy as np
import tensorflow.keras as K
import tensorflow.keras.backend as Kback
from transformers import DistilBertTokenizer, TFDistilBertModel
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %% [markdown]
# ## Dataloader

# %%
train_datagen = K.preprocessing.image.ImageDataGenerator(rescale = 1./255, validation_split = 0.3)   

train_dataset  = train_datagen.flow_from_directory(directory = '/kaggle/input/ham10000-data/HAM10000_DATA/train_dir',
                                                   target_size = (160,160),
                                                   class_mode = 'categorical',
                                                   subset = 'training',
                                                   shuffle=True,
                                                   batch_size = 64)
validation_dataset  = train_datagen.flow_from_directory(directory = '/kaggle/input/ham10000-data/HAM10000_DATA/train_dir',
                                                   target_size = (160,160),
                                                   class_mode = 'categorical',
                                                   subset = 'validation',
                                                   shuffle=True,
                                                   batch_size = 64)


test_datagen = K.preprocessing.image.ImageDataGenerator(rescale = 1./255)   

test_dataset  = test_datagen.flow_from_directory(directory = '/kaggle/input/ham10000-data/HAM10000_DATA/test_dir',
                                                   target_size = (160,160),
                                                   class_mode = 'categorical',
                                                   subset = 'training',
                                                   shuffle=False,
                                                   batch_size = 64)
# Out:
# Found 36411 images belonging to 7 classes.
# Found 15601 images belonging to 7 classes.
# Found 1103 images belonging to 7 classes.

# %%
print(train_dataset.class_indices)
print(validation_dataset.class_indices)
print(test_dataset.class_indices)
# Out:
# {'akiec': 0, 'bcc': 1, 'bkl': 2, 'df': 3, 'mel': 4, 'nv': 5, 'vasc': 6}
# {'akiec': 0, 'bcc': 1, 'bkl': 2, 'df': 3, 'mel': 4, 'nv': 5, 'vasc': 6}
# {'akiec': 0, 'bcc': 1, 'bkl': 2, 'df': 3, 'mel': 4, 'nv': 5, 'vasc': 6}

# %% [markdown]
# ## Metrics

# %%
def f1_score(y_true, y_pred):
    true_positives = Kback.sum(Kback.round(Kback.clip(y_true * y_pred, 0, 1)))
    possible_positives = Kback.sum(Kback.round(Kback.clip(y_true, 0, 1)))
    predicted_positives = Kback.sum(Kback.round(Kback.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + Kback.epsilon())
    recall = true_positives / (possible_positives + Kback.epsilon())
    f1_val = 2*(precision*recall)/(precision+recall+Kback.epsilon())
    return f1_val

METRICS = [
      "accuracy",
      K.metrics.Precision(name='precision'),
      K.metrics.Recall(name='recall'),
      K.metrics.AUC(name='auc'),
      f1_score
]

# %% [markdown]
# ## Model

# %% [markdown]
# #### CBAM

# %%
def channel_attention_module(x, ratio=8):
    batch, _, _, channel = x.shape
    ## Shared layers
    l1 = K.layers.Dense(channel//ratio, activation="relu", use_bias=False)
    l2 = K.layers.Dense(channel, use_bias=False)
    ## Global Average Pooling
    x1 = K.layers.GlobalAveragePooling2D()(x)
    x1 = l1(x1)
    x1 = l2(x1)
    ## Global Max Pooling
    x2 = K.layers.GlobalMaxPooling2D()(x)
    x2 = l1(x2)
    x2 = l2(x2)
    ## Add both the features and pass through sigmoid
    feats = x1 + x2
    feats = K.layers.Activation("sigmoid")(feats)
    feats = K.layers.Multiply()([x, feats])

    return feats

def spatial_attention_module(x):
    ## Average Pooling
    x1 = tf.reduce_mean(x, axis=-1)
    x1 = tf.expand_dims(x1, axis=-1)
    ## Max Pooling
    x2 = tf.reduce_max(x, axis=-1)
    x2 = tf.expand_dims(x2, axis=-1)
    ## Concatenat both the features
    feats = K.layers.Concatenate()([x1, x2])
    ## Conv layer
    feats = K.layers.Conv2D(1, kernel_size=7, padding="same", activation="sigmoid")(feats)
    feats = K.layers.Multiply()([x, feats])

    return feats

def cbam(x):
    x = channel_attention_module(x)
    x = spatial_attention_module(x)
    return x

# %% [markdown]
# #### Deep Learner

# %%
input_layer = K.Input(shape=(160,160,3))
deep_learner = K.applications.DenseNet121(include_top = False, weights = "imagenet", input_tensor = input_layer)
for layer in deep_learner.layers:
    layer.trainable = True
for i, layer in enumerate(deep_learner.layers):
    print(i, layer.name, "-", layer.trainable)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29084464/29084464 [==============================] - 0s 0us/step
# 0 input_1 - True
# 1 zero_padding2d - True
# 2 conv1/conv - True
# 3 conv1/bn - True
# 4 conv1/relu - True
# 5 zero_padding2d_1 - True
# 6 pool1 - True
# 7 conv2_block1_0_bn - True
# 8 conv2_block1_0_relu - True
# 9 conv2_block1_1_conv - True
# 10 conv2_block1_1_bn - True
# 11 conv2_block1_1_relu - True
# 12 conv2_block1_2_conv - True
# 13 conv2_block1_concat - True
# 14 conv2_block2_0_bn - True
# 15 conv2_block2_0_relu - True
# 16 conv2_block2_1_conv - True
# 17 conv2_block2_1_bn - True
# 18 conv2_block2_1_relu - True
# 19 conv2_block2_2_conv - True
# 20 conv2_block2_concat - True
# 21 conv2_block3_0_bn - True
# 22 conv2_block3_0_relu - True
# 23 conv2_block3_1_conv - True
# 24 conv2_block3_1_bn - True
# 25 conv2_block3_1_relu - True
# 26 conv2_block3_2_conv - True
# 27 conv2_block3_concat - True
# 28 conv2_block4_0_bn - True
# 29 conv2_block4_0_relu - True
# 30 conv2_block4_1_conv - True
# 31 conv2_block4_1_bn - True
# 32 conv2_block4_1_relu - True
# 33 conv2_block4_2_conv - True
# 34 conv2_block4_concat - True
# 35 conv2_block5_0_bn - True
# 36 conv2_block5_0_relu - True
# 37 conv2_block5_1_conv - True
# 38 conv2_block5_1_bn - True
# 39 conv2_block5_1_relu - True
# 40 conv2_block5_2_conv - True
# 41 conv2_block5_concat - True
# 42 conv2_block6_0_bn - True
# 43 conv2_block6_0_relu - True
# 44 conv2_block6_1_conv - True
# 45 conv2_block6_1_bn - True
# 46 conv2_block6_1_relu - True
# 47 conv2_block6_2_conv - True
# 48 conv2_block6_concat - True
# 49 pool2_bn - True
# 50 pool2_relu - True
# 51 pool2_conv - True
# 52 pool2_pool - True
# 53 conv3_block1_0_bn - True
# 54 conv3_block1_0_relu - True
# 55 conv3_block1_1_conv - True
# 56 conv3_block1_1_bn - True
# 57 conv3_block1_1_relu - True
# 58 conv3_block1_2_conv - True
# 59 conv3_block1_concat - True
# 60 conv3_block2_0_bn - True
# 61 conv3_block2_0_relu - True
# 62 conv3_block2_1_conv - True
# 63 conv3_block2_1_bn - True
# 64 conv3_block2_1_relu - True
# 65 conv3_block2_2_conv - True
# 66 conv3_block2_concat - True
# 67 conv3_block3_0_bn - True
# 68 conv3_block3_0_relu - True
# 69 conv3_block3_1_conv - True
# 70 conv3_block3_1_bn - True
# 71 conv3_block3_1_relu - True
# 72 conv3_block3_2_conv - True
# 73 conv3_block3_concat - True
# 74 conv3_block4_0_bn - True
# 75 conv3_block4_0_relu - True
# 76 conv3_block4_1_conv - True
# 77 conv3_block4_1_bn - True
# 78 conv3_block4_1_relu - True
# 79 conv3_block4_2_conv - True
# 80 conv3_block4_concat - True
# 81 conv3_block5_0_bn - True
# 82 conv3_block5_0_relu - True
# 83 conv3_block5_1_conv - True
# 84 conv3_block5_1_bn - True
# 85 conv3_block5_1_relu - True
# 86 conv3_block5_2_conv - True
# 87 conv3_block5_concat - True
# 88 conv3_block6_0_bn - True
# 89 conv3_block6_0_relu - True
# 90 conv3_block6_1_conv - True
# 91 conv3_block6_1_bn - True
# 92 conv3_block6_1_relu - True
# 93 conv3_block6_2_conv - True
# 94 conv3_block6_concat - True
# 95 conv3_block7_0_bn - True
# 96 conv3_block7_0_relu - True
# 97 conv3_block7_1_conv - True
# 98 conv3_block7_1_bn - True
# 99 conv3_block7_1_relu - True
# 100 conv3_block7_2_conv - True
# 101 conv3_block7_concat - True
# 102 conv3_block8_0_bn - True
# 103 conv3_block8_0_relu - True
# 104 conv3_block8_1_conv - True
# 105 conv3_block8_1_bn - True
# 106 conv3_block8_1_relu - True
# 107 conv3_block8_2_conv - True
# 108 conv3_block8_concat - True
# 109 conv3_block9_0_bn - True
# 110 conv3_block9_0_relu - True
# 111 conv3_block9_1_conv - True
# 112 conv3_block9_1_bn - True
# 113 conv3_block9_1_relu - True
# 114 conv3_block9_2_conv - True
# 115 conv3_block9_concat - True
# 116 conv3_block10_0_bn - True
# 117 conv3_block10_0_relu - True
# 118 conv3_block10_1_conv - True
# 119 conv3_block10_1_bn - True
# 120 conv3_block10_1_relu - True
# 121 conv3_block10_2_conv - True
# 122 conv3_block10_concat - True
# 123 conv3_block11_0_bn - True
# 124 conv3_block11_0_relu - True
# 125 conv3_block11_1_conv - True
# 126 conv3_block11_1_bn - True
# 127 conv3_block11_1_relu - True
# 128 conv3_block11_2_conv - True
# 129 conv3_block11_concat - True
# 130 conv3_block12_0_bn - True
# 131 conv3_block12_0_relu - True
# 132 conv3_block12_1_conv - True
# 133 conv3_block12_1_bn - True
# 134 conv3_block12_1_relu - True
# 135 conv3_block12_2_conv - True
# 136 conv3_block12_concat - True
# 137 pool3_bn - True
# 138 pool3_relu - True
# 139 pool3_conv - True
# 140 pool3_pool - True
# 141 conv4_block1_0_bn - True
# 142 conv4_block1_0_relu - True
# 143 conv4_block1_1_conv - True
# 144 conv4_block1_1_bn - True
# 145 conv4_block1_1_relu - True
# 146 conv4_block1_2_conv - True
# 147 conv4_block1_concat - True
# 148 conv4_block2_0_bn - True
# 149 conv4_block2_0_relu - True
# 150 conv4_block2_1_conv - True
# 151 conv4_block2_1_bn - True
# 152 conv4_block2_1_relu - True
# 153 conv4_block2_2_conv - True
# 154 conv4_block2_concat - True
# 155 conv4_block3_0_bn - True
# 156 conv4_block3_0_relu - True
# 157 conv4_block3_1_conv - True
# 158 conv4_block3_1_bn - True
# 159 conv4_block3_1_relu - True
# 160 conv4_block3_2_conv - True
# 161 conv4_block3_concat - True
# 162 conv4_block4_0_bn - True
# 163 conv4_block4_0_relu - True
# 164 conv4_block4_1_conv - True
# 165 conv4_block4_1_bn - True
# 166 conv4_block4_1_relu - True
# 167 conv4_block4_2_conv - True
# 168 conv4_block4_concat - True
# 169 conv4_block5_0_bn - True
# 170 conv4_block5_0_relu - True
# 171 conv4_block5_1_conv - True
# 172 conv4_block5_1_bn - True
# 173 conv4_block5_1_relu - True
# 174 conv4_block5_2_conv - True
# 175 conv4_block5_concat - True
# 176 conv4_block6_0_bn - True
# 177 conv4_block6_0_relu - True
# 178 conv4_block6_1_conv - True
# 179 conv4_block6_1_bn - True
# 180 conv4_block6_1_relu - True
# 181 conv4_block6_2_conv - True
# 182 conv4_block6_concat - True
# 183 conv4_block7_0_bn - True
# 184 conv4_block7_0_relu - True
# 185 conv4_block7_1_conv - True
# 186 conv4_block7_1_bn - True
# 187 conv4_block7_1_relu - True
# 188 conv4_block7_2_conv - True
# 189 conv4_block7_concat - True
# 190 conv4_block8_0_bn - True
# 191 conv4_block8_0_relu - True
# 192 conv4_block8_1_conv - True
# 193 conv4_block8_1_bn - True
# 194 conv4_block8_1_relu - True
# 195 conv4_block8_2_conv - True
# 196 conv4_block8_concat - True
# 197 conv4_block9_0_bn - True
# 198 conv4_block9_0_relu - True
# 199 conv4_block9_1_conv - True
# 200 conv4_block9_1_bn - True
# 201 conv4_block9_1_relu - True
# 202 conv4_block9_2_conv - True
# 203 conv4_block9_concat - True
# 204 conv4_block10_0_bn - True
# 205 conv4_block10_0_relu - True
# 206 conv4_block10_1_conv - True
# 207 conv4_block10_1_bn - True
# 208 conv4_block10_1_relu - True
# 209 conv4_block10_2_conv - True
# 210 conv4_block10_concat - True
# 211 conv4_block11_0_bn - True
# 212 conv4_block11_0_relu - True
# 213 conv4_block11_1_conv - True
# 214 conv4_block11_1_bn - True
# 215 conv4_block11_1_relu - True
# 216 conv4_block11_2_conv - True
# 217 conv4_block11_concat - True
# 218 conv4_block12_0_bn - True
# 219 conv4_block12_0_relu - True
# 220 conv4_block12_1_conv - True
# 221 conv4_block12_1_bn - True
# 222 conv4_block12_1_relu - True
# 223 conv4_block12_2_conv - True
# 224 conv4_block12_concat - True
# 225 conv4_block13_0_bn - True
# 226 conv4_block13_0_relu - True
# 227 conv4_block13_1_conv - True
# 228 conv4_block13_1_bn - True
# 229 conv4_block13_1_relu - True
# 230 conv4_block13_2_conv - True
# 231 conv4_block13_concat - True
# 232 conv4_block14_0_bn - True
# 233 conv4_block14_0_relu - True
# 234 conv4_block14_1_conv - True
# 235 conv4_block14_1_bn - True
# 236 conv4_block14_1_relu - True
# 237 conv4_block14_2_conv - True
# 238 conv4_block14_concat - True
# 239 conv4_block15_0_bn - True
# 240 conv4_block15_0_relu - True
# 241 conv4_block15_1_conv - True
# 242 conv4_block15_1_bn - True
# 243 conv4_block15_1_relu - True
# 244 conv4_block15_2_conv - True
# 245 conv4_block15_concat - True
# 246 conv4_block16_0_bn - True
# 247 conv4_block16_0_relu - True
# 248 conv4_block16_1_conv - True
# 249 conv4_block16_1_bn - True
# 250 conv4_block16_1_relu - True
# 251 conv4_block16_2_conv - True
# 252 conv4_block16_concat - True
# 253 conv4_block17_0_bn - True
# 254 conv4_block17_0_relu - True
# 255 conv4_block17_1_conv - True
# 256 conv4_block17_1_bn - True
# 257 conv4_block17_1_relu - True
# 258 conv4_block17_2_conv - True
# 259 conv4_block17_concat - True
# 260 conv4_block18_0_bn - True
# 261 conv4_block18_0_relu - True
# 262 conv4_block18_1_conv - True
# 263 conv4_block18_1_bn - True
# 264 conv4_block18_1_relu - True
# 265 conv4_block18_2_conv - True
# 266 conv4_block18_concat - True
# 267 conv4_block19_0_bn - True
# 268 conv4_block19_0_relu - True
# 269 conv4_block19_1_conv - True
# 270 conv4_block19_1_bn - True
# 271 conv4_block19_1_relu - True
# 272 conv4_block19_2_conv - True
# 273 conv4_block19_concat - True
# 274 conv4_block20_0_bn - True
# 275 conv4_block20_0_relu - True
# 276 conv4_block20_1_conv - True
# 277 conv4_block20_1_bn - True
# 278 conv4_block20_1_relu - True
# 279 conv4_block20_2_conv - True
# 280 conv4_block20_concat - True
# 281 conv4_block21_0_bn - True
# 282 conv4_block21_0_relu - True
# 283 conv4_block21_1_conv - True
# 284 conv4_block21_1_bn - True
# 285 conv4_block21_1_relu - True
# 286 conv4_block21_2_conv - True
# 287 conv4_block21_concat - True
# 288 conv4_block22_0_bn - True
# 289 conv4_block22_0_relu - True
# 290 conv4_block22_1_conv - True
# 291 conv4_block22_1_bn - True
# 292 conv4_block22_1_relu - True
# 293 conv4_block22_2_conv - True
# 294 conv4_block22_concat - True
# 295 conv4_block23_0_bn - True
# 296 conv4_block23_0_relu - True
# 297 conv4_block23_1_conv - True
# 298 conv4_block23_1_bn - True
# 299 conv4_block23_1_relu - True
# 300 conv4_block23_2_conv - True
# 301 conv4_block23_concat - True
# 302 conv4_block24_0_bn - True
# 303 conv4_block24_0_relu - True
# 304 conv4_block24_1_conv - True
# 305 conv4_block24_1_bn - True
# 306 conv4_block24_1_relu - True
# 307 conv4_block24_2_conv - True
# 308 conv4_block24_concat - True
# 309 pool4_bn - True
# 310 pool4_relu - True
# 311 pool4_conv - True
# 312 pool4_pool - True
# 313 conv5_block1_0_bn - True
# 314 conv5_block1_0_relu - True
# 315 conv5_block1_1_conv - True
# 316 conv5_block1_1_bn - True
# 317 conv5_block1_1_relu - True
# 318 conv5_block1_2_conv - True
# 319 conv5_block1_concat - True
# 320 conv5_block2_0_bn - True
# 321 conv5_block2_0_relu - True
# 322 conv5_block2_1_conv - True
# 323 conv5_block2_1_bn - True
# 324 conv5_block2_1_relu - True
# 325 conv5_block2_2_conv - True
# 326 conv5_block2_concat - True
# 327 conv5_block3_0_bn - True
# 328 conv5_block3_0_relu - True
# 329 conv5_block3_1_conv - True
# 330 conv5_block3_1_bn - True
# 331 conv5_block3_1_relu - True
# 332 conv5_block3_2_conv - True
# 333 conv5_block3_concat - True
# 334 conv5_block4_0_bn - True
# 335 conv5_block4_0_relu - True
# 336 conv5_block4_1_conv - True
# 337 conv5_block4_1_bn - True
# 338 conv5_block4_1_relu - True
# 339 conv5_block4_2_conv - True
# 340 conv5_block4_concat - True
# 341 conv5_block5_0_bn - True
# 342 conv5_block5_0_relu - True
# 343 conv5_block5_1_conv - True
# 344 conv5_block5_1_bn - True
# 345 conv5_block5_1_relu - True
# 346 conv5_block5_2_conv - True
# 347 conv5_block5_concat - True
# 348 conv5_block6_0_bn - True
# 349 conv5_block6_0_relu - True
# 350 conv5_block6_1_conv - True
# 351 conv5_block6_1_bn - True
# 352 conv5_block6_1_relu - True
# 353 conv5_block6_2_conv - True
# 354 conv5_block6_concat - True
# 355 conv5_block7_0_bn - True
# 356 conv5_block7_0_relu - True
# 357 conv5_block7_1_conv - True
# 358 conv5_block7_1_bn - True
# 359 conv5_block7_1_relu - True
# 360 conv5_block7_2_conv - True
# 361 conv5_block7_concat - True
# 362 conv5_block8_0_bn - True
# 363 conv5_block8_0_relu - True
# 364 conv5_block8_1_conv - True
# 365 conv5_block8_1_bn - True
# 366 conv5_block8_1_relu - True
# 367 conv5_block8_2_conv - True
# 368 conv5_block8_concat - True
# 369 conv5_block9_0_bn - True
# 370 conv5_block9_0_relu - True
# 371 conv5_block9_1_conv - True
# 372 conv5_block9_1_bn - True
# 373 conv5_block9_1_relu - True
# 374 conv5_block9_2_conv - True
# 375 conv5_block9_concat - True
# 376 conv5_block10_0_bn - True
# 377 conv5_block10_0_relu - True
# 378 conv5_block10_1_conv - True
# 379 conv5_block10_1_bn - True
# 380 conv5_block10_1_relu - True
# 381 conv5_block10_2_conv - True
# 382 conv5_block10_concat - True
# 383 conv5_block11_0_bn - True
# 384 conv5_block11_0_relu - True
# 385 conv5_block11_1_conv - True
# 386 conv5_block11_1_bn - True
# 387 conv5_block11_1_relu - True
# 388 conv5_block11_2_conv - True
# 389 conv5_block11_concat - True
# 390 conv5_block12_0_bn - True
# 391 conv5_block12_0_relu - True
# 392 conv5_block12_1_conv - True
# 393 conv5_block12_1_bn - True
# 394 conv5_block12_1_relu - True
# 395 conv5_block12_2_conv - True
# 396 conv5_block12_concat - True
# 397 conv5_block13_0_bn - True
# 398 conv5_block13_0_relu - True
# 399 conv5_block13_1_conv - True
# 400 conv5_block13_1_bn - True
# 401 conv5_block13_1_relu - True
# 402 conv5_block13_2_conv - True
# 403 conv5_block13_concat - True
# 404 conv5_block14_0_bn - True
# 405 conv5_block14_0_relu - True
# 406 conv5_block14_1_conv - True
# 407 conv5_block14_1_bn - True
# 408 conv5_block14_1_relu - True
# 409 conv5_block14_2_conv - True
# 410 conv5_block14_concat - True
# 411 conv5_block15_0_bn - True
# 412 conv5_block15_0_relu - True
# 413 conv5_block15_1_conv - True
# 414 conv5_block15_1_bn - True
# 415 conv5_block15_1_relu - True
# 416 conv5_block15_2_conv - True
# 417 conv5_block15_concat - True
# 418 conv5_block16_0_bn - True
# 419 conv5_block16_0_relu - True
# 420 conv5_block16_1_conv - True
# 421 conv5_block16_1_bn - True
# 422 conv5_block16_1_relu - True
# 423 conv5_block16_2_conv - True
# 424 conv5_block16_concat - True
# 425 bn - True
# 426 relu - True

# %% [markdown]
# #### Model

# %%
input_img = K.layers.Input(shape=(160,160,3)) 
feat_img = deep_learner(input_img)
flat = K.layers.GlobalAveragePooling2D()(feat_img)
output = K.layers.Dense(7, activation='softmax')(flat)

model = K.Model(inputs=input_img, outputs=output)
optimizer = K.optimizers.Adam(lr=0.01)
model.compile(loss=["categorical_crossentropy"], metrics=METRICS, optimizer = optimizer)
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 160, 160, 3  0           []
#                                 )]
#
#  densenet121 (Functional)       (None, 5, 5, 1024)   7037504     ['input_3[0][0]']
#
#  global_average_pooling2d_2 (Gl  (None, 1024)        0           ['densenet121[1][0]']
#  obalAveragePooling2D)
#
#  global_max_pooling2d_1 (Global  (None, 1024)        0           ['densenet121[1][0]']
#  MaxPooling2D)
#
#  dense_3 (Dense)                (None, 128)          131072      ['global_average_pooling2d_2[0][0
#                                                                  ]',
#                                                                   'global_max_pooling2d_1[0][0]']
#
#  dense_4 (Dense)                (None, 1024)         131072      ['dense_3[0][0]',
#                                                                   'dense_3[1][0]']
#
#  tf.__operators__.add_1 (TFOpLa  (None, 1024)        0           ['dense_4[0][0]',
#  mbda)                                                            'dense_4[1][0]']
#
#  activation_1 (Activation)      (None, 1024)         0           ['tf.__operators__.add_1[0][0]']
#
#  multiply_2 (Multiply)          (None, 5, 5, 1024)   0           ['densenet121[1][0]',
#                                                                   'activation_1[0][0]']
#
#  tf.math.reduce_mean_1 (TFOpLam  (None, 5, 5)        0           ['multiply_2[0][0]']
#  bda)
#
#  tf.math.reduce_max_1 (TFOpLamb  (None, 5, 5)        0           ['multiply_2[0][0]']
#  da)
#
#  tf.expand_dims_2 (TFOpLambda)  (None, 5, 5, 1)      0           ['tf.math.reduce_mean_1[0][0]']
#
#  tf.expand_dims_3 (TFOpLambda)  (None, 5, 5, 1)      0           ['tf.math.reduce_max_1[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 5, 5, 2)      0           ['tf.expand_dims_2[0][0]',
#                                                                   'tf.expand_dims_3[0][0]']
#
#  conv2d_1 (Conv2D)              (None, 5, 5, 1)      99          ['concatenate_1[0][0]']
#
#  multiply_3 (Multiply)          (None, 5, 5, 1024)   0           ['multiply_2[0][0]',
#                                                                   'conv2d_1[0][0]']
#
#  global_average_pooling2d_3 (Gl  (None, 1024)        0           ['multiply_3[0][0]']
#  obalAveragePooling2D)
#
#  dense_5 (Dense)                (None, 7)            7175        ['global_average_pooling2d_3[0][0
#                                                                  ]']
#
# ==================================================================================================
# Total params: 7,306,922
# Trainable params: 7,223,274
# Non-trainable params: 83,648
# __________________________________________________________________________________________________

# %% [markdown]
# ## Training

# %%
model_checkpoint_callback = K.callbacks.ModelCheckpoint(
    filepath='densenet121.h5',
    monitor='val_f1_score',
    save_best_only=True,
    mode='max',
    verbose=1
    )

history = model.fit(train_dataset,
                    epochs = 50,
                    validation_data = validation_dataset,
                    verbose = 1,
                    callbacks=[model_checkpoint_callback],
                    shuffle = True)
# Out:
# Epoch 1/50
# 569/569 [==============================] - ETA: 0s - loss: 0.6522 - accuracy: 0.7540 - precision: 0.8227 - recall: 0.6830 - auc: 0.9639 - f1_score: 0.7414
# Epoch 1: val_f1_score improved from -inf to 0.51386, saving model to densenet121_cbam.h5
# 569/569 [==============================] - 536s 783ms/step - loss: 0.6522 - accuracy: 0.7540 - precision: 0.8227 - recall: 0.6830 - auc: 0.9639 - f1_score: 0.7414 - val_loss: 1.6662 - val_accuracy: 0.5227 - val_precision: 0.5402 - val_recall: 0.4902 - val_auc: 0.8595 - val_f1_score: 0.5139
# Epoch 2/50
# 569/569 [==============================] - ETA: 0s - loss: 0.3792 - accuracy: 0.8584 - precision: 0.8873 - recall: 0.8313 - auc: 0.9868 - f1_score: 0.8582
# Epoch 2: val_f1_score did not improve from 0.51386
# 569/569 [==============================] - 274s 482ms/step - loss: 0.3792 - accuracy: 0.8584 - precision: 0.8873 - recall: 0.8313 - auc: 0.9868 - f1_score: 0.8582 - val_loss: 8.9552 - val_accuracy: 0.3601 - val_precision: 0.3615 - val_recall: 0.3537 - val_auc: 0.6883 - val_f1_score: 0.3574
# Epoch 3/50
# 569/569 [==============================] - ETA: 0s - loss: 0.2714 - accuracy: 0.9023 - precision: 0.9175 - recall: 0.8874 - auc: 0.9926 - f1_score: 0.9020
# Epoch 3: val_f1_score did not improve from 0.51386
# 569/569 [==============================] - 276s 486ms/step - loss: 0.2714 - accuracy: 0.9023 - precision: 0.9175 - recall: 0.8874 - auc: 0.9926 - f1_score: 0.9020 - val_loss: 4.0652 - val_accuracy: 0.4148 - val_precision: 0.4323 - val_recall: 0.4013 - val_auc: 0.7202 - val_f1_score: 0.4161
# Epoch 4/50
# 569/569 [==============================] - ETA: 0s - loss: 0.2120 - accuracy: 0.9230 - precision: 0.9333 - recall: 0.9125 - auc: 0.9953 - f1_score: 0.9227
# Epoch 4: val_f1_score improved from 0.51386 to 0.52250, saving model to densenet121_cbam.h5
# 569/569 [==============================] - 275s 484ms/step - loss: 0.2120 - accuracy: 0.9230 - precision: 0.9333 - recall: 0.9125 - auc: 0.9953 - f1_score: 0.9227 - val_loss: 3.6761 - val_accuracy: 0.5227 - val_precision: 0.5346 - val_recall: 0.5109 - val_auc: 0.7977 - val_f1_score: 0.5225
# Epoch 5/50
# 569/569 [==============================] - ETA: 0s - loss: 0.1769 - accuracy: 0.9366 - precision: 0.9447 - recall: 0.9287 - auc: 0.9966 - f1_score: 0.9366
# Epoch 5: val_f1_score did not improve from 0.52250
# 569/569 [==============================] - 274s 482ms/step - loss: 0.1769 - accuracy: 0.9366 - precision: 0.9447 - recall: 0.9287 - auc: 0.9966 - f1_score: 0.9366 - val_loss: 4.0912 - val_accuracy: 0.4298 - val_precision: 0.4420 - val_recall: 0.4238 - val_auc: 0.7406 - val_f1_score: 0.4326
# Epoch 6/50
# 569/569 [==============================] - ETA: 0s - loss: 0.1474 - accuracy: 0.9466 - precision: 0.9528 - recall: 0.9406 - auc: 0.9974 - f1_score: 0.9466
# Epoch 6: val_f1_score improved from 0.52250 to 0.58607, saving model to densenet121_cbam.h5
# 569/569 [==============================] - 278s 489ms/step - loss: 0.1474 - accuracy: 0.9466 - precision: 0.9528 - recall: 0.9406 - auc: 0.9974 - f1_score: 0.9466 - val_loss: 2.2562 - val_accuracy: 0.5854 - val_precision: 0.6004 - val_recall: 0.5728 - val_auc: 0.8517 - val_f1_score: 0.5861
# Epoch 7/50
# 569/569 [==============================] - ETA: 0s - loss: 0.1304 - accuracy: 0.9520 - precision: 0.9565 - recall: 0.9475 - auc: 0.9980 - f1_score: 0.9519
# Epoch 7: val_f1_score did not improve from 0.58607
# 569/569 [==============================] - 276s 484ms/step - loss: 0.1304 - accuracy: 0.9520 - precision: 0.9565 - recall: 0.9475 - auc: 0.9980 - f1_score: 0.9519 - val_loss: 2.4273 - val_accuracy: 0.5453 - val_precision: 0.5537 - val_recall: 0.5366 - val_auc: 0.8395 - val_f1_score: 0.5449
# Epoch 8/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0993 - accuracy: 0.9641 - precision: 0.9673 - recall: 0.9612 - auc: 0.9987 - f1_score: 0.9642
# Epoch 8: val_f1_score did not improve from 0.58607
# 569/569 [==============================] - 275s 483ms/step - loss: 0.0993 - accuracy: 0.9641 - precision: 0.9673 - recall: 0.9612 - auc: 0.9987 - f1_score: 0.9642 - val_loss: 6.5086 - val_accuracy: 0.4036 - val_precision: 0.4067 - val_recall: 0.3966 - val_auc: 0.7056 - val_f1_score: 0.4014
# Epoch 9/50
# 569/569 [==============================] - ETA: 0s - loss: 0.1080 - accuracy: 0.9609 - precision: 0.9643 - recall: 0.9576 - auc: 0.9983 - f1_score: 0.9609
# Epoch 9: val_f1_score did not improve from 0.58607
# 569/569 [==============================] - 278s 488ms/step - loss: 0.1080 - accuracy: 0.9609 - precision: 0.9643 - recall: 0.9576 - auc: 0.9983 - f1_score: 0.9609 - val_loss: 3.4987 - val_accuracy: 0.4338 - val_precision: 0.4445 - val_recall: 0.4259 - val_auc: 0.7624 - val_f1_score: 0.4350
# Epoch 10/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0806 - accuracy: 0.9716 - precision: 0.9736 - recall: 0.9696 - auc: 0.9989 - f1_score: 0.9716
# Epoch 10: val_f1_score improved from 0.58607 to 0.61087, saving model to densenet121_cbam.h5
# 569/569 [==============================] - 275s 483ms/step - loss: 0.0806 - accuracy: 0.9716 - precision: 0.9736 - recall: 0.9696 - auc: 0.9989 - f1_score: 0.9716 - val_loss: 2.7890 - val_accuracy: 0.6101 - val_precision: 0.6177 - val_recall: 0.6043 - val_auc: 0.8485 - val_f1_score: 0.6109
# Epoch 11/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0801 - accuracy: 0.9718 - precision: 0.9737 - recall: 0.9698 - auc: 0.9990 - f1_score: 0.9717
# Epoch 11: val_f1_score did not improve from 0.61087
# 569/569 [==============================] - 274s 482ms/step - loss: 0.0801 - accuracy: 0.9718 - precision: 0.9737 - recall: 0.9698 - auc: 0.9990 - f1_score: 0.9717 - val_loss: 4.8130 - val_accuracy: 0.5007 - val_precision: 0.5080 - val_recall: 0.4948 - val_auc: 0.7639 - val_f1_score: 0.5014
# Epoch 12/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0675 - accuracy: 0.9760 - precision: 0.9778 - recall: 0.9747 - auc: 0.9993 - f1_score: 0.9762
# Epoch 12: val_f1_score improved from 0.61087 to 0.72483, saving model to densenet121_cbam.h5
# 569/569 [==============================] - 274s 482ms/step - loss: 0.0675 - accuracy: 0.9760 - precision: 0.9778 - recall: 0.9747 - auc: 0.9993 - f1_score: 0.9762 - val_loss: 1.5385 - val_accuracy: 0.7253 - val_precision: 0.7328 - val_recall: 0.7176 - val_auc: 0.9152 - val_f1_score: 0.7248
# Epoch 13/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0703 - accuracy: 0.9751 - precision: 0.9766 - recall: 0.9739 - auc: 0.9991 - f1_score: 0.9753
# Epoch 13: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 274s 481ms/step - loss: 0.0703 - accuracy: 0.9751 - precision: 0.9766 - recall: 0.9739 - auc: 0.9991 - f1_score: 0.9753 - val_loss: 5.1628 - val_accuracy: 0.4887 - val_precision: 0.4944 - val_recall: 0.4837 - val_auc: 0.7627 - val_f1_score: 0.4889
# Epoch 14/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0640 - accuracy: 0.9770 - precision: 0.9784 - recall: 0.9756 - auc: 0.9993 - f1_score: 0.9770
# Epoch 14: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 274s 481ms/step - loss: 0.0640 - accuracy: 0.9770 - precision: 0.9784 - recall: 0.9756 - auc: 0.9993 - f1_score: 0.9770 - val_loss: 2.9832 - val_accuracy: 0.5478 - val_precision: 0.5543 - val_recall: 0.5430 - val_auc: 0.8202 - val_f1_score: 0.5486
# Epoch 15/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0525 - accuracy: 0.9813 - precision: 0.9821 - recall: 0.9804 - auc: 0.9995 - f1_score: 0.9813
# Epoch 15: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 273s 479ms/step - loss: 0.0525 - accuracy: 0.9813 - precision: 0.9821 - recall: 0.9804 - auc: 0.9995 - f1_score: 0.9813 - val_loss: 6.8985 - val_accuracy: 0.4861 - val_precision: 0.4897 - val_recall: 0.4816 - val_auc: 0.7616 - val_f1_score: 0.4856
# Epoch 16/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0513 - accuracy: 0.9824 - precision: 0.9836 - recall: 0.9815 - auc: 0.9994 - f1_score: 0.9826
# Epoch 16: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 276s 485ms/step - loss: 0.0513 - accuracy: 0.9824 - precision: 0.9836 - recall: 0.9815 - auc: 0.9994 - f1_score: 0.9826 - val_loss: 5.7356 - val_accuracy: 0.4554 - val_precision: 0.4596 - val_recall: 0.4513 - val_auc: 0.7358 - val_f1_score: 0.4554
# Epoch 17/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0459 - accuracy: 0.9845 - precision: 0.9853 - recall: 0.9838 - auc: 0.9995 - f1_score: 0.9845
# Epoch 17: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 273s 480ms/step - loss: 0.0459 - accuracy: 0.9845 - precision: 0.9853 - recall: 0.9838 - auc: 0.9995 - f1_score: 0.9845 - val_loss: 2.8271 - val_accuracy: 0.6044 - val_precision: 0.6132 - val_recall: 0.5983 - val_auc: 0.8472 - val_f1_score: 0.6057
# Epoch 18/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0518 - accuracy: 0.9823 - precision: 0.9833 - recall: 0.9815 - auc: 0.9993 - f1_score: 0.9824
# Epoch 18: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 273s 479ms/step - loss: 0.0518 - accuracy: 0.9823 - precision: 0.9833 - recall: 0.9815 - auc: 0.9993 - f1_score: 0.9824 - val_loss: 3.9881 - val_accuracy: 0.5459 - val_precision: 0.5518 - val_recall: 0.5393 - val_auc: 0.8021 - val_f1_score: 0.5454
# Epoch 19/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0469 - accuracy: 0.9840 - precision: 0.9848 - recall: 0.9831 - auc: 0.9994 - f1_score: 0.9840
# Epoch 19: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 273s 480ms/step - loss: 0.0469 - accuracy: 0.9840 - precision: 0.9848 - recall: 0.9831 - auc: 0.9994 - f1_score: 0.9840 - val_loss: 2.8427 - val_accuracy: 0.6277 - val_precision: 0.6324 - val_recall: 0.6237 - val_auc: 0.8570 - val_f1_score: 0.6280
# Epoch 20/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0404 - accuracy: 0.9860 - precision: 0.9867 - recall: 0.9856 - auc: 0.9996 - f1_score: 0.9861
# Epoch 20: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 275s 483ms/step - loss: 0.0404 - accuracy: 0.9860 - precision: 0.9867 - recall: 0.9856 - auc: 0.9996 - f1_score: 0.9861 - val_loss: 5.8421 - val_accuracy: 0.5280 - val_precision: 0.5314 - val_recall: 0.5246 - val_auc: 0.7814 - val_f1_score: 0.5281
# Epoch 21/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0414 - accuracy: 0.9856 - precision: 0.9862 - recall: 0.9849 - auc: 0.9995 - f1_score: 0.9856
# Epoch 21: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 297s 521ms/step - loss: 0.0414 - accuracy: 0.9856 - precision: 0.9862 - recall: 0.9849 - auc: 0.9995 - f1_score: 0.9856 - val_loss: 3.2638 - val_accuracy: 0.6453 - val_precision: 0.6503 - val_recall: 0.6412 - val_auc: 0.8572 - val_f1_score: 0.6457
# Epoch 22/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0329 - accuracy: 0.9892 - precision: 0.9896 - recall: 0.9888 - auc: 0.9995 - f1_score: 0.9892
# Epoch 22: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 276s 485ms/step - loss: 0.0329 - accuracy: 0.9892 - precision: 0.9896 - recall: 0.9888 - auc: 0.9995 - f1_score: 0.9892 - val_loss: 6.2535 - val_accuracy: 0.4763 - val_precision: 0.4819 - val_recall: 0.4728 - val_auc: 0.7381 - val_f1_score: 0.4772
# Epoch 23/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0383 - accuracy: 0.9876 - precision: 0.9882 - recall: 0.9871 - auc: 0.9994 - f1_score: 0.9877
# Epoch 23: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 273s 480ms/step - loss: 0.0383 - accuracy: 0.9876 - precision: 0.9882 - recall: 0.9871 - auc: 0.9994 - f1_score: 0.9877 - val_loss: 7.9295 - val_accuracy: 0.5793 - val_precision: 0.5814 - val_recall: 0.5757 - val_auc: 0.7985 - val_f1_score: 0.5784
# Epoch 24/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0314 - accuracy: 0.9898 - precision: 0.9902 - recall: 0.9892 - auc: 0.9996 - f1_score: 0.9897
# Epoch 24: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 275s 483ms/step - loss: 0.0314 - accuracy: 0.9898 - precision: 0.9902 - recall: 0.9892 - auc: 0.9996 - f1_score: 0.9897 - val_loss: 2.5523 - val_accuracy: 0.5598 - val_precision: 0.5659 - val_recall: 0.5497 - val_auc: 0.8386 - val_f1_score: 0.5577
# Epoch 25/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0358 - accuracy: 0.9888 - precision: 0.9895 - recall: 0.9882 - auc: 0.9995 - f1_score: 0.9889
# Epoch 25: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 272s 479ms/step - loss: 0.0358 - accuracy: 0.9888 - precision: 0.9895 - recall: 0.9882 - auc: 0.9995 - f1_score: 0.9889 - val_loss: 3.3529 - val_accuracy: 0.5535 - val_precision: 0.5606 - val_recall: 0.5483 - val_auc: 0.8160 - val_f1_score: 0.5544
# Epoch 26/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0310 - accuracy: 0.9892 - precision: 0.9897 - recall: 0.9889 - auc: 0.9997 - f1_score: 0.9893
# Epoch 26: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 273s 479ms/step - loss: 0.0310 - accuracy: 0.9892 - precision: 0.9897 - recall: 0.9889 - auc: 0.9997 - f1_score: 0.9893 - val_loss: 2.3056 - val_accuracy: 0.6653 - val_precision: 0.6698 - val_recall: 0.6605 - val_auc: 0.8741 - val_f1_score: 0.6651
# Epoch 27/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0250 - accuracy: 0.9920 - precision: 0.9923 - recall: 0.9918 - auc: 0.9997 - f1_score: 0.9920
# Epoch 27: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 273s 479ms/step - loss: 0.0250 - accuracy: 0.9920 - precision: 0.9923 - recall: 0.9918 - auc: 0.9997 - f1_score: 0.9920 - val_loss: 5.8807 - val_accuracy: 0.4576 - val_precision: 0.4600 - val_recall: 0.4534 - val_auc: 0.7482 - val_f1_score: 0.4568
# Epoch 28/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0308 - accuracy: 0.9897 - precision: 0.9903 - recall: 0.9894 - auc: 0.9996 - f1_score: 0.9898
# Epoch 28: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 272s 478ms/step - loss: 0.0308 - accuracy: 0.9897 - precision: 0.9903 - recall: 0.9894 - auc: 0.9996 - f1_score: 0.9898 - val_loss: 2.2027 - val_accuracy: 0.6419 - val_precision: 0.6485 - val_recall: 0.6367 - val_auc: 0.8739 - val_f1_score: 0.6424
# Epoch 29/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0325 - accuracy: 0.9894 - precision: 0.9899 - recall: 0.9890 - auc: 0.9996 - f1_score: 0.9894
# Epoch 29: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 273s 480ms/step - loss: 0.0325 - accuracy: 0.9894 - precision: 0.9899 - recall: 0.9890 - auc: 0.9996 - f1_score: 0.9894 - val_loss: 39.0983 - val_accuracy: 0.1833 - val_precision: 0.1832 - val_recall: 0.1831 - val_auc: 0.5328 - val_f1_score: 0.1832
# Epoch 30/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0263 - accuracy: 0.9912 - precision: 0.9914 - recall: 0.9908 - auc: 0.9997 - f1_score: 0.9911
# Epoch 30: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 275s 483ms/step - loss: 0.0263 - accuracy: 0.9912 - precision: 0.9914 - recall: 0.9908 - auc: 0.9997 - f1_score: 0.9911 - val_loss: 7.1280 - val_accuracy: 0.5664 - val_precision: 0.5704 - val_recall: 0.5632 - val_auc: 0.7904 - val_f1_score: 0.5668
# Epoch 31/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0192 - accuracy: 0.9936 - precision: 0.9937 - recall: 0.9935 - auc: 0.9998 - f1_score: 0.9936
# Epoch 31: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 272s 478ms/step - loss: 0.0192 - accuracy: 0.9936 - precision: 0.9937 - recall: 0.9935 - auc: 0.9998 - f1_score: 0.9936 - val_loss: 1.9406 - val_accuracy: 0.6837 - val_precision: 0.6930 - val_recall: 0.6781 - val_auc: 0.8922 - val_f1_score: 0.6854
# Epoch 32/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0345 - accuracy: 0.9890 - precision: 0.9894 - recall: 0.9887 - auc: 0.9995 - f1_score: 0.9890
# Epoch 32: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 274s 482ms/step - loss: 0.0345 - accuracy: 0.9890 - precision: 0.9894 - recall: 0.9887 - auc: 0.9995 - f1_score: 0.9890 - val_loss: 5.4912 - val_accuracy: 0.5011 - val_precision: 0.5041 - val_recall: 0.4971 - val_auc: 0.7686 - val_f1_score: 0.5005
# Epoch 33/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0180 - accuracy: 0.9937 - precision: 0.9939 - recall: 0.9936 - auc: 0.9998 - f1_score: 0.9938
# Epoch 33: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 271s 477ms/step - loss: 0.0180 - accuracy: 0.9937 - precision: 0.9939 - recall: 0.9936 - auc: 0.9998 - f1_score: 0.9938 - val_loss: 4.6732 - val_accuracy: 0.5112 - val_precision: 0.5150 - val_recall: 0.5080 - val_auc: 0.7770 - val_f1_score: 0.5115
# Epoch 34/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0288 - accuracy: 0.9902 - precision: 0.9907 - recall: 0.9896 - auc: 0.9996 - f1_score: 0.9901
# Epoch 34: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 271s 476ms/step - loss: 0.0288 - accuracy: 0.9902 - precision: 0.9907 - recall: 0.9896 - auc: 0.9996 - f1_score: 0.9901 - val_loss: 4.4147 - val_accuracy: 0.5090 - val_precision: 0.5162 - val_recall: 0.5046 - val_auc: 0.7759 - val_f1_score: 0.5102
# Epoch 35/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0239 - accuracy: 0.9920 - precision: 0.9923 - recall: 0.9917 - auc: 0.9997 - f1_score: 0.9920
# Epoch 35: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 272s 478ms/step - loss: 0.0239 - accuracy: 0.9920 - precision: 0.9923 - recall: 0.9917 - auc: 0.9997 - f1_score: 0.9920 - val_loss: 9.8595 - val_accuracy: 0.5171 - val_precision: 0.5195 - val_recall: 0.5136 - val_auc: 0.7630 - val_f1_score: 0.5164
# Epoch 36/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0246 - accuracy: 0.9916 - precision: 0.9920 - recall: 0.9913 - auc: 0.9997 - f1_score: 0.9917
# Epoch 36: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 273s 480ms/step - loss: 0.0246 - accuracy: 0.9916 - precision: 0.9920 - recall: 0.9913 - auc: 0.9997 - f1_score: 0.9917 - val_loss: 13.1481 - val_accuracy: 0.4440 - val_precision: 0.4465 - val_recall: 0.4412 - val_auc: 0.7168 - val_f1_score: 0.4438
# Epoch 37/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0178 - accuracy: 0.9944 - precision: 0.9946 - recall: 0.9942 - auc: 0.9998 - f1_score: 0.9944
# Epoch 37: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 273s 479ms/step - loss: 0.0178 - accuracy: 0.9944 - precision: 0.9946 - recall: 0.9942 - auc: 0.9998 - f1_score: 0.9944 - val_loss: 9.8617 - val_accuracy: 0.6038 - val_precision: 0.6071 - val_recall: 0.6005 - val_auc: 0.8141 - val_f1_score: 0.6036
# Epoch 38/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0220 - accuracy: 0.9928 - precision: 0.9931 - recall: 0.9926 - auc: 0.9998 - f1_score: 0.9928
# Epoch 38: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 276s 485ms/step - loss: 0.0220 - accuracy: 0.9928 - precision: 0.9931 - recall: 0.9926 - auc: 0.9998 - f1_score: 0.9928 - val_loss: 2.6028 - val_accuracy: 0.6428 - val_precision: 0.6486 - val_recall: 0.6393 - val_auc: 0.8648 - val_f1_score: 0.6438
# Epoch 39/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0249 - accuracy: 0.9918 - precision: 0.9922 - recall: 0.9916 - auc: 0.9997 - f1_score: 0.9919
# Epoch 39: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 273s 480ms/step - loss: 0.0249 - accuracy: 0.9918 - precision: 0.9922 - recall: 0.9916 - auc: 0.9997 - f1_score: 0.9919 - val_loss: 9.0807 - val_accuracy: 0.5445 - val_precision: 0.5473 - val_recall: 0.5418 - val_auc: 0.7863 - val_f1_score: 0.5444
# Epoch 40/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0173 - accuracy: 0.9944 - precision: 0.9945 - recall: 0.9942 - auc: 0.9998 - f1_score: 0.9943
# Epoch 40: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 274s 481ms/step - loss: 0.0173 - accuracy: 0.9944 - precision: 0.9945 - recall: 0.9942 - auc: 0.9998 - f1_score: 0.9943 - val_loss: 4.3899 - val_accuracy: 0.6366 - val_precision: 0.6386 - val_recall: 0.6350 - val_auc: 0.8366 - val_f1_score: 0.6367
# Epoch 41/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0198 - accuracy: 0.9931 - precision: 0.9934 - recall: 0.9928 - auc: 0.9998 - f1_score: 0.9931
# Epoch 41: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 273s 479ms/step - loss: 0.0198 - accuracy: 0.9931 - precision: 0.9934 - recall: 0.9928 - auc: 0.9998 - f1_score: 0.9931 - val_loss: 8.3822 - val_accuracy: 0.4757 - val_precision: 0.4778 - val_recall: 0.4733 - val_auc: 0.7359 - val_f1_score: 0.4755
# Epoch 42/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0144 - accuracy: 0.9956 - precision: 0.9957 - recall: 0.9955 - auc: 0.9998 - f1_score: 0.9956
# Epoch 42: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 272s 478ms/step - loss: 0.0144 - accuracy: 0.9956 - precision: 0.9957 - recall: 0.9955 - auc: 0.9998 - f1_score: 0.9956 - val_loss: 10.2047 - val_accuracy: 0.5664 - val_precision: 0.5694 - val_recall: 0.5637 - val_auc: 0.7875 - val_f1_score: 0.5665
# Epoch 43/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0238 - accuracy: 0.9921 - precision: 0.9924 - recall: 0.9917 - auc: 0.9997 - f1_score: 0.9920
# Epoch 43: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 274s 482ms/step - loss: 0.0238 - accuracy: 0.9921 - precision: 0.9924 - recall: 0.9917 - auc: 0.9997 - f1_score: 0.9920 - val_loss: 7.8802 - val_accuracy: 0.3729 - val_precision: 0.3743 - val_recall: 0.3707 - val_auc: 0.6769 - val_f1_score: 0.3724
# Epoch 44/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0253 - accuracy: 0.9921 - precision: 0.9924 - recall: 0.9918 - auc: 0.9996 - f1_score: 0.9921
# Epoch 44: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 274s 482ms/step - loss: 0.0253 - accuracy: 0.9921 - precision: 0.9924 - recall: 0.9918 - auc: 0.9996 - f1_score: 0.9921 - val_loss: 2.9518 - val_accuracy: 0.6479 - val_precision: 0.6504 - val_recall: 0.6462 - val_auc: 0.8555 - val_f1_score: 0.6483
# Epoch 45/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0092 - accuracy: 0.9971 - precision: 0.9973 - recall: 0.9970 - auc: 0.9999 - f1_score: 0.9971
# Epoch 45: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 272s 478ms/step - loss: 0.0092 - accuracy: 0.9971 - precision: 0.9973 - recall: 0.9970 - auc: 0.9999 - f1_score: 0.9971 - val_loss: 2.2796 - val_accuracy: 0.6895 - val_precision: 0.6941 - val_recall: 0.6855 - val_auc: 0.8834 - val_f1_score: 0.6898
# Epoch 46/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0249 - accuracy: 0.9917 - precision: 0.9918 - recall: 0.9914 - auc: 0.9996 - f1_score: 0.9916
# Epoch 46: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 273s 480ms/step - loss: 0.0249 - accuracy: 0.9917 - precision: 0.9918 - recall: 0.9914 - auc: 0.9996 - f1_score: 0.9916 - val_loss: 2.9961 - val_accuracy: 0.6577 - val_precision: 0.6613 - val_recall: 0.6549 - val_auc: 0.8562 - val_f1_score: 0.6580
# Epoch 47/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0142 - accuracy: 0.9951 - precision: 0.9953 - recall: 0.9950 - auc: 0.9998 - f1_score: 0.9951
# Epoch 47: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 273s 480ms/step - loss: 0.0142 - accuracy: 0.9951 - precision: 0.9953 - recall: 0.9950 - auc: 0.9998 - f1_score: 0.9951 - val_loss: 5.2486 - val_accuracy: 0.4639 - val_precision: 0.4668 - val_recall: 0.4611 - val_auc: 0.7497 - val_f1_score: 0.4639
# Epoch 48/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0144 - accuracy: 0.9953 - precision: 0.9954 - recall: 0.9952 - auc: 0.9998 - f1_score: 0.9953
# Epoch 48: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 273s 479ms/step - loss: 0.0144 - accuracy: 0.9953 - precision: 0.9954 - recall: 0.9952 - auc: 0.9998 - f1_score: 0.9953 - val_loss: 6.1084 - val_accuracy: 0.4024 - val_precision: 0.4055 - val_recall: 0.3989 - val_auc: 0.7082 - val_f1_score: 0.4022
# Epoch 49/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0195 - accuracy: 0.9937 - precision: 0.9938 - recall: 0.9935 - auc: 0.9998 - f1_score: 0.9937
# Epoch 49: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 276s 485ms/step - loss: 0.0195 - accuracy: 0.9937 - precision: 0.9938 - recall: 0.9935 - auc: 0.9998 - f1_score: 0.9937 - val_loss: 2.6288 - val_accuracy: 0.6782 - val_precision: 0.6824 - val_recall: 0.6747 - val_auc: 0.8735 - val_f1_score: 0.6785
# Epoch 50/50
# 569/569 [==============================] - ETA: 0s - loss: 0.0160 - accuracy: 0.9945 - precision: 0.9946 - recall: 0.9944 - auc: 0.9998 - f1_score: 0.9945
# Epoch 50: val_f1_score did not improve from 0.72483
# 569/569 [==============================] - 274s 481ms/step - loss: 0.0160 - accuracy: 0.9945 - precision: 0.9946 - recall: 0.9944 - auc: 0.9998 - f1_score: 0.9945 - val_loss: 6.4830 - val_accuracy: 0.4660 - val_precision: 0.4696 - val_recall: 0.4625 - val_auc: 0.7368 - val_f1_score: 0.4660

# %% [markdown]
# #### Training plots

# %%
import matplotlib.pyplot as plt

def Train_Val_Plot(acc, val_acc, loss, val_loss, auc, val_auc, precision, val_precision, recall, val_recall, f1_score, val_f1_score):
    fig, axes = plt.subplots(2, 3, figsize=(20, 10))
    fig.suptitle("MODEL'S METRICS VISUALIZATION")

    axes[0, 0].plot(range(1, len(acc) + 1), acc)
    axes[0, 0].plot(range(1, len(val_acc) + 1), val_acc)
    axes[0, 0].set_title('History of Accuracy')
    axes[0, 0].set_xlabel('Epochs')
    axes[0, 0].set_ylabel('Accuracy')
    axes[0, 0].legend(['training', 'validation'])

    axes[0, 1].plot(range(1, len(loss) + 1), loss)
    axes[0, 1].plot(range(1, len(val_loss) + 1), val_loss)
    axes[0, 1].set_title('History of Loss')
    axes[0, 1].set_xlabel('Epochs')
    axes[0, 1].set_ylabel('Loss')
    axes[0, 1].legend(['training', 'validation'])

    axes[0, 2].plot(range(1, len(auc) + 1), auc)
    axes[0, 2].plot(range(1, len(val_auc) + 1), val_auc)
    axes[0, 2].set_title('History of AUC')
    axes[0, 2].set_xlabel('Epochs')
    axes[0, 2].set_ylabel('AUC')
    axes[0, 2].legend(['training', 'validation'])

    axes[1, 0].plot(range(1, len(precision) + 1), precision)
    axes[1, 0].plot(range(1, len(val_precision) + 1), val_precision)
    axes[1, 0].set_title('History of Precision')
    axes[1, 0].set_xlabel('Epochs')
    axes[1, 0].set_ylabel('Precision')
    axes[1, 0].legend(['training', 'validation'])

    axes[1, 1].plot(range(1, len(recall) + 1), recall)
    axes[1, 1].plot(range(1, len(val_recall) + 1), val_recall)
    axes[1, 1].set_title('History of Recall')
    axes[1, 1].set_xlabel('Epochs')
    axes[1, 1].set_ylabel('Recall')
    axes[1, 1].legend(['training', 'validation'])

    axes[1, 2].plot(range(1, len(f1_score) + 1), f1_score)
    axes[1, 2].plot(range(1, len(val_f1_score) + 1), val_f1_score)
    axes[1, 2].set_title('History of F1 score')
    axes[1, 2].set_xlabel('Epochs')
    axes[1, 2].set_ylabel('Recall')  # Corrected from 'Recall' to 'F1 score'
    axes[1, 2].legend(['training', 'validation'])

    plt.tight_layout()
    plt.show()

# Call the function with your history data
Train_Val_Plot(history.history['accuracy'], history.history['val_accuracy'],
               history.history['loss'], history.history['val_loss'],
               history.history['auc'], history.history['val_auc'],
               history.history['precision'], history.history['val_precision'],
               history.history['recall'], history.history['val_recall'],
               history.history['f1_score'], history.history['val_f1_score'])

# %% [markdown]
# ## Testing

# %%
model = K.models.load_model("/kaggle/working/densenet121.h5", custom_objects={"f1_score": f1_score})

# Evaluate the model
loss, accuracy, precision, recall, auc, f1_score = model.evaluate(test_dataset)
loss, accuracy, precision, recall, auc, f1_score = model.evaluate(test_dataset)
print("Accuracy", accuracy)
print("Loss", loss)
print("Precision", precision)
print("Recall", recall)
print("AUC", auc)
print("F1-score", f1_score)
# Out:
# 18/18 [==============================] - 23s 1s/step - loss: 0.7105 - accuracy: 0.8631 - precision: 0.8669 - recall: 0.8622 - auc: 0.9665 - f1_score: 0.8669
# 18/18 [==============================] - 8s 456ms/step - loss: 0.7105 - accuracy: 0.8631 - precision: 0.8669 - recall: 0.8622 - auc: 0.9665 - f1_score: 0.8669
# Accuracy 0.8631006479263306
# Loss 0.7105001211166382
# Precision 0.8669097423553467
# Recall 0.8621940016746521
# AUC 0.9664795398712158
# F1-score 0.866863489151001

# %%
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay
Y_pred = model.predict_generator(test_dataset, 1157)
y_pred = np.argmax(Y_pred, axis=1)
print('Confusion Matrix')
disp = ConfusionMatrixDisplay(confusion_matrix(test_dataset.classes, y_pred),display_labels=['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc'])
disp.plot()
plt.show()
print('Classification Report')
target_names = ['akiec', 'bcc', 'bkl', 'df', 'mel', 'nv', 'vasc']
print(classification_report(test_dataset.classes, y_pred, target_names=target_names))
# Out:
# /tmp/ipykernel_29/493592024.py:2: UserWarning: `Model.predict_generator` is deprecated and will be removed in a future version. Please use `Model.predict`, which supports generators.
#   Y_pred = model.predict_generator(test_dataset, 1157)
# Confusion Matrix
# Classification Report
#               precision    recall  f1-score   support
#
#        akiec       0.89      0.27      0.41        30
#          bcc       0.58      0.60      0.59        35
#          bkl       0.49      0.57      0.53        88
#           df       0.55      0.75      0.63         8
#          mel       0.68      0.28      0.40        46
#           nv       0.92      0.95      0.94       883
#         vasc       0.92      0.92      0.92        13
#
#     accuracy                           0.86      1103
#    macro avg       0.72      0.62      0.63      1103
# weighted avg       0.86      0.86      0.85      1103
